# %% [markdown]
# <a href="https://colab.research.google.com/github/jssilva3/Colaboratory2/blob/master/Copia_de_Ejercicio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
np="4"
if np == "1":
        print ("fallo en el refresco de la memoria")
elif np == "2":
          print (" fallo de memoria. Error de paridad")
elif np == "3":
      print("Fallo en la memoria base de 64K")
elif np == "4":
      print("fallo en el timer del sistema.")
else:
      print ("Error desconocido")
# Out:
# fallo en el timer del sistema.
